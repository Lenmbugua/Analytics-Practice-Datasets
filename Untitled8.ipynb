# %%
#READING IN FILES

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\njeri\Desktop\Python\scraped.csv", header = None, names = ['Ticket', 'Status'])
# Out:
#      Ticket  Status
# 0     58898  CLOSED
# 1     75342  CLOSED
# 2     58869  CLOSED
# 3     71741  CLOSED
# 4     70899  CLOSED
# ..      ...     ...
# 233   68377  CLOSED
# 234   75574  CLOSED
# 235   75564    OPEN
# 236   75431  CLOSED
# 237   73596  CLOSED
#
# [238 rows x 2 columns]

# %%
df = pd.read_csv(r"C:\Users\njeri\Desktop\Python\scraped.csv")
df
# Out:
#      58898  CLOSED
# 0    75342  CLOSED
# 1    58869  CLOSED
# 2    71741  CLOSED
# 3    70899  CLOSED
# 4    74305  CLOSED
# ..     ...     ...
# 232  68377  CLOSED
# 233  75574  CLOSED
# 234  75564    OPEN
# 235  75431  CLOSED
# 236  73596  CLOSED
#
# [237 rows x 2 columns]

# %%
df = pd.read_csv(r"C:\Users\njeri\Documents\Ticket #74837.txt")
df
# Out:
#   /* Update of EBM status in eTIMS to enable the Taxpayer generate invoices
# 0                                   Ticket #74837 */
# 1  update myrra.taxpayer_base set ebm_ty_cd='02' ...
# 2                                            commit;

# %%
df2 = pd.read_excel(r"C:\Users\njeri\Ticket #76044.xlsx")
df2
# Out:
#              PIN                      TAXPAYER NAME          ISSUE    STATUS
# 0    A001517425S             RONARD MOCHONI ONSONGO  DATA MIGRATION      VAT
# 1    A001242099R                     Ezekiel Otieno  DATA MIGRATION  NON VAT
# 2    A001258407Z                 cleaveland onyango  DATA MIGRATION  NON VAT
# 3    A001294167T                      NELSON MWAURA  DATA MIGRATION  NON VAT
# 4    A001699764S              VINCENT EKESA WABWIRE  DATA MIGRATION  NON VAT
# ..           ...                                ...             ...      ...
# 142  P052316797U              JKB SOLUTIONS LIMITED  DATA MIGRATION  NON VAT
# 143  P052316954L        BENIHYA ENTERPRISES LIMITED  DATA MIGRATION  NON VAT
# 144  P052317157I                  BLACKLEAF LIMITED  DATA MIGRATION  NON VAT
# 145  P052317499V  Caketa Farming Revolution Limited  DATA MIGRATION  NON VAT
# 146  P052317782P       ANALOG & DIGITAL SYSTMES LTD  DATA MIGRATION  NON VAT
#
# [147 rows x 4 columns]

# %%
pd.set_option('display.max.rows', 175)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PIN            147 non-null    object
#  1   TAXPAYER NAME  147 non-null    object
#  2   ISSUE          147 non-null    object
#  3   STATUS         147 non-null    object
# dtypes: object(4)
# memory usage: 4.7+ KB

# %%
df2.shape
# Out:
# (147, 4)

# %%
df2.head(10)
# Out:
#            PIN             TAXPAYER NAME          ISSUE    STATUS
# 0  A001517425S    RONARD MOCHONI ONSONGO  DATA MIGRATION      VAT
# 1  A001242099R            Ezekiel Otieno  DATA MIGRATION  NON VAT
# 2  A001258407Z        cleaveland onyango  DATA MIGRATION  NON VAT
# 3  A001294167T             NELSON MWAURA  DATA MIGRATION  NON VAT
# 4  A001699764S     VINCENT EKESA WABWIRE  DATA MIGRATION  NON VAT
# 5  A001722463T        JOSEPH KAMAU NGUGI  DATA MIGRATION  NON VAT
# 6  A001773936A        Peter Sakwa Akulia  DATA MIGRATION  NON VAT
# 7  A002266631Z        Julius Mutiso Muli  DATA MIGRATION  NON VAT
# 8  A002440773P  MICHAEL BWIRE MASAKHALIA  DATA MIGRATION  NON VAT
# 9  A002503326I    Michael Osere Nyongesa  DATA MIGRATION  NON VAT

# %%
df2.tail(10)
# Out:
#              PIN                      TAXPAYER NAME          ISSUE    STATUS
# 137  P052309533F          Realcode Networks Limited  DATA MIGRATION  NON VAT
# 138  P052312165W           BANTECH SERVICES LIMITED  DATA MIGRATION  NON VAT
# 139  P052313190Z             Germdeal Suppliers Ltd  DATA MIGRATION  NON VAT
# 140  P052313856E    EMKAY FARMS & TRADE SYSTEMS LTD  DATA MIGRATION  NON VAT
# 141  P052314886M          XELOD ENTERPRISES LIMITED  DATA MIGRATION  NON VAT
# 142  P052316797U              JKB SOLUTIONS LIMITED  DATA MIGRATION  NON VAT
# 143  P052316954L        BENIHYA ENTERPRISES LIMITED  DATA MIGRATION  NON VAT
# 144  P052317157I                  BLACKLEAF LIMITED  DATA MIGRATION  NON VAT
# 145  P052317499V  Caketa Farming Revolution Limited  DATA MIGRATION  NON VAT
# 146  P052317782P       ANALOG & DIGITAL SYSTMES LTD  DATA MIGRATION  NON VAT

# %%
df2.rank
# Out:
# <bound method NDFrame.rank of              PIN                                      TAXPAYER NAME  \
# 0    A001517425S                             RONARD MOCHONI ONSONGO
# 1    A001242099R                                     Ezekiel Otieno
# 2    A001258407Z                                 cleaveland onyango
# 3    A001294167T                                      NELSON MWAURA
# 4    A001699764S                              VINCENT EKESA WABWIRE
# 5    A001722463T                                 JOSEPH KAMAU NGUGI
# 6    A001773936A                                 Peter Sakwa Akulia
# 7    A002266631Z                                 Julius Mutiso Muli
# 8    A002440773P                           MICHAEL BWIRE MASAKHALIA
# 9    A002503326I                             Michael Osere Nyongesa
# 10   A002701401X                            Nicholas Gatiba Kirangi
# 11   A002708816Y                                DAVID EFUMBI BARASA
# ...

# %%
df2.loc[146]
# Out:
# PIN                               P052317782P
# TAXPAYER NAME    ANALOG & DIGITAL SYSTMES LTD
# ISSUE                          DATA MIGRATION
# STATUS                                NON VAT
# Name: 146, dtype: object

# %%
df2.iloc[146]
# Out:
# PIN                               P052317782P
# TAXPAYER NAME    ANALOG & DIGITAL SYSTMES LTD
# ISSUE                          DATA MIGRATION
# STATUS                                NON VAT
# Name: 146, dtype: object
