# %% [markdown]
# ** Netflix Dataset Project**
# This project is about Netflix dataset which has information about the TV shows and movies available in Netflix.
#
# The Dataset is available on Kaggle.
#
# It provides various metadata such as the type of content, cast, genres, country of origin, release details, and more. This dataset can be useful for content analysis, recommendation system development, or trend studies.
#
# This dataset is collected from Flixable which is a third-party Netflix search engin
#
# Task 1;
# We started by removing duplicates in this dataset.  Here we use duplicated() function.
# Task 2;
# Is there any null values present in the column? Show with heat map. Here we use the isnull() Function.
#
# Using this dataset, we answered multiple questions with Python in our Project.
# Q. 1) For 'House of Cards', what is the Show Id and Who is the Director of this show  - For this question we used the isin() function and the str.contains() function.?
#
# Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.
#
# Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.
#
# Q. 4) Show all the Movies that were released in year 2000.
#
# Q. 5) Show only the Titles of all TV Shows that were released in India only.
#
# Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?
#
# Q. 7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".
#
# Q. 8) In how many movies/shows, Tom Cruise was cast ?
#
# Q. 9) What are the different Ratings defined by Netflix ?
# Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?
# Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?
#
# Q. 10) What is the maximum duration of a Movie/Show on Netflix ?
#
# Q. 11) Which individual country has the Highest No. of TV Shows ?
#
# Q. 12) How can we sort the dataset by Year ?
#
# Q. 13) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.e.

# %%
#importing the dataset
import pandas as pd
df = pd.read_csv("Netflix Dataset.csv")

# %%
df.head()               # used to show the top five number of rows in the dataset.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()               # used to show the bottom five rows in the dataset
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape        #used to show no of rows and columns
# Out:
# (7789, 11)

# %%
df.size     #used to show no of total values(elements) in the dataset
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.columns        # used to show each column name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes        #used to show datatype of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()                        # To show indexes, columns, datatypes of each column memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df[df.duplicated()]                                 # To check row wise and detect the duplicate rows.
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description  is_duplicate
# 6300  When two would-be robbers accidentally kill a ...          True
# 6622  A disillusioned security guard transforms into...          True

# %%
df[df.duplicated(keep=False)]           # This one shows the originals and the copies
# Out:
#      Show_Id Category              Title        Director  \
# 683     s684    Movie           Backfire     Dave Patten
# 4839   s6621    Movie  The Lost Okoroshi  Abba T. Makama
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 683   Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 4839  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 683       April 5, 2019  TV-MA   97 min
# 4839  September 4, 2020  TV-MA   94 min
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 683   Dramas, Independent Movies, Thrillers
# ...

# %%
df.drop_duplicates( inplace = True)                      # here we have used inplace = True to drop the duplicates permanently

# %%
df[df.duplicated()]                             # we are checking if there are duplicates after we have permanently deleted them.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, is_duplicate]
# Index: []

# %%
df.isnull()                        # To show where null values are present. Where there is a True shows there is a null value and where there is false there is no null value.
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description  is_duplicate
# 0      False     False  False        False         False
# ...

# %%
df.isnull().sum()                        # Used to show the count of null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# is_duplicate       0
# dtype: int64

# %%
# Import seaborn library to show with heat-map
import seaborn as sns                             #import seaborn library
sns.heatmap(df.isnull())                          # Using heat-map to show null values count
# Out:
# <Axes: >

# %% [markdown]
# q1. #For 'House of Cards', what is the Show Id and Who is the Director of this show?

# %%
df[df['Title'].isin(['House of Cards'])]                                #To show all records of a particular item in any column
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description  is_duplicate
# 2832  A ruthless politician will stop at nothing to ...         False

# %%
# Using str.contains() function to answer quiz one
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description  is_duplicate
# 2832  A ruthless politician will stop at nothing to ...         False

# %%
df.loc[df['Title'] == 'House of Cards', ['Title', 'Show_Id', 'Director']]     # Here i have used the .loc function to filter out the specific columns that were asked in quiz one
# Out:
#                Title Show_Id  \
# 2832  House of Cards   s2833
#
#                                                Director
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph

# %%
df.dtypes                       # Here we are checking the specific columns that we have in that dataset.
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# is_duplicate      bool
# dtype: object

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'].str.strip(), errors='coerce')     # create a column called Date_N

# %%
df.head()     # check if the column Date_N is created
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df['Date_N'].dt.year.value_counts()      # Counts the occurence of all indiividual years in Date column.
# Out:
# Date_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# BAR GRAPH

# %%
df['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df.head(2)                              # This shows where the movies and tv shows lie in which column which shows Category
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description  is_duplicate     Date_N
# 0  In a future where the elite inhabit an island ...         False 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit...         False 2016-12-23

# %% [markdown]
# For this question we will use the groupby().

# %%
df.groupby('Category').Category.count()          # To group all unique items of a column and show their count.
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# Use the countplot() function to show the bargraph.

# %%
sns.countplot(x='Category', data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# Q. 4) Show all the Movies that were released in year 2000.

# %%
df.head(2)                           # have a look at our data to tell which column we are working with
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description  is_duplicate     Date_N
# 0  In a future where the elite inhabit an island ...         False 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit...         False 2016-12-23

# %%
df['Year'] = df['Date_N'].dt.year            # create a new column called year which considers only year

# %%
df.head(2)                 # check if the column year has been created
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description  is_duplicate     Date_N  \
# 0  In a future where the elite inhabit an island ...         False 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit...         False 2016-12-23
#
#      Year
# 0  2020.0
# 1  2016.0

# %% [markdown]
# To answer this question we will apply a filter

# %%
df[(df['Category'] == 'Movie') & (df ['Year'] == 2000)]  # The movie is in Category column we refer to it and for the year 2000 we refer to Year column.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, is_duplicate, Date_N, Year]
# Index: []

# %% [markdown]
# Q. 5) Show only the Titles of all TV Shows that were released in India only.

# %%
df.loc[(df['Category'] == 'TV Show') & (df['Country'] == 'India'), 'Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ? - To answer this question we use valuecount() function.

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
#  7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom". - For this question we use the and & or operator together with filter.

# %%
df[(df['Category'] == 'Movie') & (df['Type'] == 'Comedies')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
df[(df['Category'] == 'Movie') & (df['Type'] == 'Comedies') | (df['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# Q. 8) In how many movies/shows, Tom Cruise was cast ?

# %%
df[df.Cast == 'Tom Cruise']     # This filtering gave us 0 because it does not apply whenever we have more than one element in a column
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, is_duplicate, Date_N, Year]
# Index: []

# %% [markdown]
# Use str.Contains() to answer that question

# %%
df[df['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df[df['Cast'].str.contains('Tom Cruise')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
#     131         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %% [markdown]
# # To solve the error above; we remove the null values from our dataset using dropna() function

# %%
df_new = df.dropna()       # it drops all rows that contains all missing values.

# %%
df_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
df_new[df_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description  is_duplicate  \
# 3860  Through chance, human action, past history and...         False
# 5071  A fast-talking yuppie is forced to slow down w...         False
#
#          Date_N    Year
# 3860 2020-01-01  2020.0
# 5071 2019-07-01  2019.0

# %% [markdown]
# Q. 9) What are the different Ratings defined by Netflix ?  - For this i have used nunique to show the count of the ratings available and unique() to show the different ratings available

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
df[(df['Category'] =='Movie')  & (df ['Rating'] =='TV-14')].shape
# Out:
# (1272, 14)

# %%
df[(df['Category'] =='Movie')  & (df ['Rating'] =='TV-14') & (df['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %% [markdown]
# Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
df[(df['Category'] == 'TV Show') & (df ['Rating']== 'R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description  is_duplicate  \
# 4497  A series of incidents in Afghanistan set compl...         False
# 6437  Trapped at a stagecoach stop as a storm rages ...         False
#
# ...

# %%
df[(df['Category'] == 'TV Show') & (df ['Rating']== 'R') & (df [year])]
